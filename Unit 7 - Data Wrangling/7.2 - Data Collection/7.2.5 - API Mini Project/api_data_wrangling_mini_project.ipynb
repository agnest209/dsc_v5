# %% [markdown]
# This exercise will require you to pull some data from https://data.nasdaq.com/ (formerly Quandl API).

# %% [markdown]
# As a first step, you will need to register a free account on the https://data.nasdaq.com/ website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:
#
# *Note*: Use a `.env` file and put your key in there and `python-dotenv` to access it in this notebook.
#
# The code below uses a key that was used when generating this project but has since been deleted. Never submit your keys to source control. There is a `.env-example` file in this repository to illusrtate what you need. Copy that to a file called `.env` and use your own api key in that `.env` file. Make sure you also have a `.gitignore` file with a line for `.env` added to it.
#
# The standard Python gitignore is [here](https://github.com/github/gitignore/blob/master/Python.gitignore) you can just copy that.

# %%
# get api key from your .env file
import os
from dotenv import load_dotenv

load_dotenv()
API_KEY = os.getenv('NASDAQ_API_KEY')

print(API_KEY)
# Out:
# None

# %% [markdown]
# Nasdaq Data has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Nasdaq Data API instructions here: https://docs.data.nasdaq.com/docs/in-depth-usage

# %% [markdown]
# While there is a dedicated Python package for connecting to the Nasdaq API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# First, import the relevant modules
import requests
from collections import defaultdict
import json

# %% [markdown]
# Note: API's can change a bit with each version, for this exercise it is reccomended to use the nasdaq api at `https://data.nasdaq.com/api/v3/`. This is the same api as what used to be quandl so `https://www.quandl.com/api/v3/` should work too.
#
# Hint: We are looking for the `AFX_X` data on the `datasets/FSE/` dataset.

# %%
# Now, call the Nasdaq API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned

# curl "https://data.nasdaq.com/api/v3/datasets/WIKI/FB/data.json?api_key=YOURAPIKEY"

params = defaultdict(api_key=API_KEY)
url = 'https://data.nasdaq.com/api/v3/datasets/FSE/AFX_X/data.json'
res = requests.get(url, params=params)

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure

json = res.json()
print(json)
# Out:
# {'dataset_data': {'limit': None, 'transform': None, 'column_index': None, 'column_names': ['Date', 'Open', 'High', 'Low', 'Close', 'Change', 'Traded Volume', 'Turnover', 'Last Price of the Day', 'Daily Traded Units', 'Daily Turnover'], 'start_date': '2000-06-07', 'end_date': '2020-12-01', 'frequency': 'daily', 'data': [['2020-12-01', 112.2, 112.2, 111.5, 112.0, None, 51.0, 5703.0, None, None, None], ['2020-11-30', 111.0, 113.6, 111.0, 112.1, None, 315.0, 35111.5, None, None, None], ['2020-11-27', 111.0, 111.5, 109.5, 111.2, None, 155.0, 17168.5, None, None, None], ['2020-11-26', 111.3, 112.0, 110.5, 111.6, None, 254.0, 28367.5, None, None, None], ['2020-11-25', 111.4, 111.4, 110.1, 110.1, None, 294.0, 32435.8, None, None, None], ['2020-11-24', 116.1, 116.8, 110.5, 113.5, None, 3184.0, 361404.4, None, None, None], ['2020-11-23', 118.0, 118.8, 116.3, 116.3, None, 1590.0, 187525.0, None, None, None], ['2020-11-20', 116.5, 118.0, 116.5, 117.5, None, 295.0, 34736.0, None, None, None], ['2
# ...

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %%
## TASK 1 : Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, 
##          for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD)

## *** QUESTION: WHY DO WE NEED TO USE DEFAULTDICT HERE ? WHY DOES JUST DICT NOT WORK? ***
params2017 = defaultdict(api_key= API_KEY, start_date= '2017-01-01', end_date= '2017-12-31')

url = 'https://data.nasdaq.com/api/v3/datasets/FSE/AFX_X/data.json'
res2017 = requests.get(url, params=params)

## TASK 2 : Convert the returned JSON object into a Python dictionary
dict2017 = res.json()
print(dict2017)
# Out:
# {'dataset_data': {'limit': None, 'transform': None, 'column_index': None, 'column_names': ['Date', 'Open', 'High', 'Low', 'Close', 'Change', 'Traded Volume', 'Turnover', 'Last Price of the Day', 'Daily Traded Units', 'Daily Turnover'], 'start_date': '2000-06-07', 'end_date': '2020-12-01', 'frequency': 'daily', 'data': [['2020-12-01', 112.2, 112.2, 111.5, 112.0, None, 51.0, 5703.0, None, None, None], ['2020-11-30', 111.0, 113.6, 111.0, 112.1, None, 315.0, 35111.5, None, None, None], ['2020-11-27', 111.0, 111.5, 109.5, 111.2, None, 155.0, 17168.5, None, None, None], ['2020-11-26', 111.3, 112.0, 110.5, 111.6, None, 254.0, 28367.5, None, None, None], ['2020-11-25', 111.4, 111.4, 110.1, 110.1, None, 294.0, 32435.8, None, None, None], ['2020-11-24', 116.1, 116.8, 110.5, 113.5, None, 3184.0, 361404.4, None, None, None], ['2020-11-23', 118.0, 118.8, 116.3, 116.3, None, 1590.0, 187525.0, None, None, None], ['2020-11-20', 116.5, 118.0, 116.5, 117.5, None, 295.0, 34736.0, None, None, None], ['2
# ...

# %%
## TASK 3 : Calculate what the highest and lowest opening prices were for the stock in this period
open_data = []
for row in dict2017['dataset_data']['data']:
    if row[1] != None: 
        open_data.append(row[1])
    
print(len(open_data))
print(open_data)
# Out:
# 4536
# ...

# %%
## TASK 3 (cont): Calculate what the highest and lowest opening prices were for the stock in this period
max(open_data) # the highest opening price for the stock in this period
# Out:
# 122.1

# %%
## TASK 3 (cont): Calculate what the highest and lowest opening prices were for the stock in this period
min(open_data) # the lowest opening price for the stock in this period
# Out:
# 4.2

# %%
## TASK 4 : What was the largest change in any one day (based on High and Low price)?
high_data = []
low_data = []
for row in dict2017['dataset_data']['data']:
    if row[2] != None: 
        high_data.append(row[2])
    if row[3] != None:
        low_data.append(row[3])
    
print(len(high_data))
print(len(low_data))
print(high_data)
print(low_data)
# Out:
# 4867
# 4867
# ...

# %%
## TASK 4 (cont) : What was the largest change in any one day (based on High and Low price)?
day_change = []
for i in range(len(high_data)):
    day_change.append(high_data[i]-low_data[i])
print(day_change)
# Out:
# [0.7000000000000028, 2.5999999999999943, 2.0, 1.5, 1.3000000000000114, 6.299999999999997, 2.5, 1.5, 0.0, 0.7999999999999972, 2.200000000000003, 1.7000000000000028, 1.7999999999999972, 1.0999999999999943, 2.299999999999997, 3.8000000000000114, 3.8000000000000114, 1.0, 1.5, 4.0, 1.5999999999999943, 3.5, 5.700000000000003, 6.299999999999997, 7.6000000000000085, 0.8999999999999915, 4.099999999999994, 6.099999999999994, 3.1000000000000085, 2.0, 1.4000000000000057, 2.1000000000000085, 3.8000000000000114, 2.700000000000003, 3.5, 3.1000000000000085, 4.799999999999997, 2.299999999999997, 2.4000000000000057, 1.4000000000000057, 1.3999999999999915, 1.6000000000000085, 1.5999999999999943, 1.4000000000000057, 1.7999999999999972, 2.5, 2.299999999999997, 1.4000000000000057, 3.299999999999997, 1.1000000000000085, 1.5, 3.5, 1.1000000000000085, 6.0, 2.8500000000000085, 0.3499999999999943, 0.09999999999999432, 1.3499999999999943, 1.0499999999999972, 1.4499999999999886, 3.0, 2.450000000000003, 1.3499999
# ...

# %%
## TASK 4 (cont) : What was the largest change in any one day (based on High and Low price)?
print(max(day_change)) # largest change in any one day (based on High and Low price)
# Out:
# 14.099999999999994

# %%
## TASK 5 : What was the largest change between any two days (based on Closing Price)?
close_data = []
for row in dict2017['dataset_data']['data']:
    if row[4] != None: 
        close_data.append(row[4])
    
print(len(close_data))
print(close_data)
# Out:
# 5268
# ...

# %%
## TASK 5 (cont) : What was the largest change between any two days (based on Closing Price)?
twoday_change = []
for i in range(len(close_data)):
    if ((len(close_data)-1)-i) >= 2:
        twoday_change.append(close_data[i+2]-close_data[i])
print(twoday_change)
# Out:
# [-0.7999999999999972, -0.5, -1.1000000000000085, 1.9000000000000057, 6.200000000000003, 4.0, -0.7000000000000028, -2.5, 0.10000000000000853, 3.0999999999999943, 1.5, -1.6999999999999886, -0.29999999999999716, -1.8000000000000114, 2.5, 0.5, -4.0, -1.2999999999999972, -5.400000000000006, -5.700000000000003, 0.7000000000000028, 1.4000000000000057, 1.0999999999999943, 5.400000000000006, 1.9000000000000057, 3.5999999999999943, 7.799999999999997, 2.0999999999999943, 1.7000000000000028, 2.200000000000003, -1.7999999999999972, -4.099999999999994, 0.6999999999999886, 0.0, -1.5999999999999943, -2.5, -6.0, -3.5, -2.700000000000003, -1.7999999999999972, -2.200000000000003, -1.4000000000000057, -2.799999999999997, -0.09999999999999432, 0.29999999999999716, -5.700000000000003, -3.299999999999997, -2.0, -3.799999999999997, -3.5, 1.2000000000000028, 3.799999999999997, -5.25, -9.599999999999994, -2.950000000000003, 0.09999999999999432, 1.5499999999999972, 3.3499999999999943, 0.20000000000000284, 0.10
# ...

# %%
## TASK 5 (cont) : What was the largest change between any two days (based on Closing Price)?
print(max(twoday_change)) # the largest change between any two days (based on Closing Price)
# Out:
# 10.349999999999994

# %%
## TASK 6 : What was the average daily trading volume during this year?
volume_data = []
for row in dict2017['dataset_data']['data']:
    if row[6] != None: 
        volume_data.append(row[6])
    
print(len(volume_data))
print(volume_data)
# Out:
# 5222
# ...

# %%
## TASK 6 (cont): What was the average daily trading volume during this year?
print(sum(volume_data)/len(volume_data)) # avg daily trading volume during 2017
# Out:
# 57692.61126005362

# %%
len(volume_data)%2
# Out:
# 0

# %%
## TASK 7 : (Optional) What was the median trading volume during this year. 
##          (Note: you may need to implement your own function for calculating the median.)
def median(data):
    '''
    Calculate median for stock trading data.
    
    Precondition: data is of type list.
    '''
    if (len(data)%2) == 0: # length of data is an even number, so median will be avg of middle two numbers
        first_middle_index = len(data)/2
        second_middle_index = (len(data)/2) + 1
        median = (data[int(first_middle_index)]+data[int(second_middle_index)])/2
    else: # length of data is an odd number, so median is just the middle number
        middle_index = len(data)/2
        median = data[int(middle_index)]
    return median

print(median(volume_data)) ## median trading volume during 2017
# Out:
# 11722.0
